# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc">
#   <ul class="toc-item">
#     <li>
#       <ul class="toc-item">
#         <li>
#           <ul class="toc-item">
#             <li>
#               <ul class="toc-item">
#                 <li>
#                   <span><a href="#Цель:-Построить-модель-для-классификации-комментариев-на-позитивные-и-негативные." data-toc-modified-id="Цель:-Построить-модель-для-классификации-комментариев-на-позитивные-и-негативные.-0.0.0.1"><span class="toc-item-num">0.0.0.1&nbsp;&nbsp;</span>Цель: Построить модель для классификации комментариев на позитивные и негативные.</a></span>
#                 </li>
#                 <li>
#                   <span><a href="#Условия:" data-toc-modified-id="Условия:-0.0.0.2"><span class="toc-item-num">0.0.0.2&nbsp;&nbsp;</span>Условия:</a></span>
#                 </li>
#                 <li>
#                   <span><a href="#Задачи:" data-toc-modified-id="Задачи:-0.0.0.3"><span class="toc-item-num">0.0.0.3&nbsp;&nbsp;</span>Задачи:</a></span>
#                 </li>
#                 <li>
#                   <span><a href="#Этапы-исследования:" data-toc-modified-id="Этапы-исследования:-0.0.0.4"><span class="toc-item-num">0.0.0.4&nbsp;&nbsp;</span>Этапы исследования:</a></span>
#                 </li>
#                 <li>
#                   <span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.0.0.5"><span class="toc-item-num">0.0.0.5&nbsp;&nbsp;</span>Описание данных</a></span>
#                 </li>
#               </ul>
#             </li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#     <li>
#       <span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span>
#       <ul class="toc-item">
#         <li>
#           <span><a href="#Создаем-облако-слов" data-toc-modified-id="Создаем-облако-слов-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Создаем облако слов</a></span>
#         </li>
#         <li>
#           <span><a href="#Частотный-анализ-текста" data-toc-modified-id="Частотный-анализ-текста-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Частотный анализ текста</a></span>
#         </li>
#       </ul>
#     </li>
#     <li>
#       <span><a href="#Обучение" data-toc-modified-id="Обучение-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обучение</a></span>
#       <ul class="toc-item">
#         <li>
#           <span><a href="#LogisticRegression-(Pipeline-+-GridSearchCV)" data-toc-modified-id="LogisticRegression-(Pipeline-+-GridSearchCV)-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>LogisticRegression (Pipeline + GridSearchCV)</a></span>
#         </li>
#         <li>
#           <span><a href="#RidgeClassifier-(Pipeline-+-GridSearchCV)" data-toc-modified-id="RidgeClassifier-(Pipeline-+-GridSearchCV)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>RidgeClassifier (Pipeline + GridSearchCV)</a></span>
#         </li>
#         <li>
#           <span><a href="#SGDClassifier-(Pipeline-+-GridSearchCV)" data-toc-modified-id="SGDClassifier-(Pipeline-+-GridSearchCV)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>SGDClassifier (Pipeline + GridSearchCV)</a></span>
#         </li>
#         <li>
#           <span><a href="#LGBMClassifier-(Pipeline-+-GridSearchCV)" data-toc-modified-id="LGBMClassifier-(Pipeline-+-GridSearchCV)-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>LGBMClassifier (Pipeline + GridSearchCV)</a></span>
#         </li>
#       </ul>
#     </li>
#     <li>
#       <span><a href="#Выводы" data-toc-modified-id="Выводы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Выводы</a></span>
#     </li>
#     <li>
#       <span><a href="#Проект-для-«Викишоп»" data-toc-modified-id="Проект-для-«Викишоп»-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проект для «Викишоп»</a></span>
#       <ul class="toc-item">
#         <li>
#           <ul class="toc-item">
#             <li>
#               <span><a href="#Нами-были-выполнены-следующие-этапы-исследования:" data-toc-modified-id="Нами-были-выполнены-следующие-этапы-исследования:-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>Нами были выполнены следующие этапы исследования:</a></span>
#             </li>
#             <li>
#               <span><a href="#Нами-были-выполнены-все-условия:" data-toc-modified-id="Нами-были-выполнены-все-условия:-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>Нами были выполнены все условия:</a></span>
#             </li>
#             <li>
#               <span><a href="#В-результате-исследования-мы-смогли-сделать-следующие-выводы:" data-toc-modified-id="В-результате-исследования-мы-смогли-сделать-следующие-выводы:-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>В результате исследования мы смогли сделать следующие выводы:</a></span>
#             </li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#   </ul>
# </div>

# %% [markdown]
# # Проект для «Викишоп»
#
# - Интернет-магазин «Викишоп» запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
#
# ## План проекта:
#
# ##### Цель:
# Построить модель для классификации комментариев на позитивные и негативные.
#
# ##### Условия:
#  - Построить модель со значением метрики качества F1 не меньше 0.75.
#
# ##### Задачи:
#  - Обучить модель классифицировать комментарии на позитивные и негативные (в нашем распоряжении набор данных с разметкой о токсичности правок).
#
# ##### Этапы исследования:
# 1. Общий обзор данных ( выведение общей информации и примера данных);
# 1. Провести предобработку данных ( изучить данные; заполнить пропущенные значения и обработать аномалии в столбцах; если среди признаков имеются неинформативные, то удалить их);
# 1. Подготовить выборки для обучения моделей;
# 1. Анализ данных ( непосредственно на данном этапе мы будем выполнять поставленные нами задачи);
# 1. Вывод и заключение.
#
# По ходу выполнения всех этапов проекта мы будем делать промежуточные выводы, которые помогут нам сделать конечные выводы.
#
# ##### Описание данных
# Текст комментария:
#  - Столбец "text"
#
# Целевой признак:
#  - Столбец "toxic"

# %% [markdown]
# ## Подготовка

# %%
# Импорт библиотек для обработки текста и машинного обучения
from sklearn.feature_extraction.text import (
    TfidfVectorizer,
    CountVectorizer,
    TfidfTransformer,
)
from sklearn.metrics import (
    f1_score,
    precision_score,
    recall_score,
    accuracy_score,
    roc_auc_score,
    roc_curve,
    precision_recall_curve,
    plot_precision_recall_curve,
)
from sklearn.linear_model import (
    LogisticRegression,
    RidgeClassifier,
    SGDClassifier,
)
from sklearn.model_selection import (
    train_test_split,
    cross_val_score,
    GridSearchCV,
    cross_val_predict,
)
from pandarallel import pandarallel
from tqdm.notebook import tqdm
from pymystem3 import Mystem
from IPython.display import display
import sweetviz as sv
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.utils import shuffle
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import lightgbm as lgb
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from tqdm import notebook, tqdm
import transformers
import torch
from spacy.lang.en import English
import spacy
import warnings
import random
import requests
import string

# Импорт библиотек для обработки текста и анализа данных
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
import re
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords as nltk_stopwords
from nltk.probability import FreqDist
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')

# Загрузка модели spaCy
nlp = spacy.load("en_core_web_sm")

# Инициализация параллельных вычислений для Pandas
pandarallel.initialize(progress_bar=True)

# Отключение предупреждений
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/kolotukhin.md/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kolotukhin.md/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kolotukhin.md/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
df = pd.read_csv(
    '/Users/kolotukhin.md/Downloads/jupyter_notebook/11/toxic_comments.csv', index_col=0)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data = df.copy()

# %% [markdown]
# - Выведем общую информацию.

# %%
def get_data_info(data):
    display(data.sample(5))
    display(data.info())

# %%
get_data_info(data)
# Out:
#                                                      text  toxic
# 55284   "\n\nAngkor\nHey I love Cambodia and Angkor to...      0
# 60614   This album is very similar to Clayman in all a...      0
# 103751  "\n\n Pope John Paul II Peer review \n\nHi DrK...      0
# 118377  Welcome!\n\nHello, , and welcome to Wikipedia!...      0
# 78964   Temazepam\nI reverted your edits since they ap...      0
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159292 entries, 0 to 159450
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    159292 non-null  object
#  1   toxic   159292 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.6+ MB
# None

# %% [markdown]
#  - Рассмотрим соотношение токсичных и нетоксичных комментариев.

# %%
def check_balance(data):
    print(round((data['toxic'].value_counts(normalize=True)), 3))

check_balance(data)
# Out:
# 0    0.898
# 1    0.102
# Name: toxic, dtype: float64

# %%
ratio = data['toxic'].value_counts(normalize=(0, 1))
ratio.plot(kind='bar', grid=True)
plt.xlabel("Тип комментария.")
plt.ylabel("Часть от целого.")
plt.title("Соотношение токсичных и нетоксичных комментариев.")
plt.show()

# %%
display(data['toxic'].value_counts())
class_ratio = data['toxic'].value_counts()[0] / data['toxic'].value_counts()[1]
# Out:
# 0    143106
# 1     16186
# Name: toxic, dtype: int64

# %% [markdown]
#  - Проведем анализ на дубликаты и на поиск пропусков в данных.

# %%
# выведем количество дубликатов
print(data.duplicated().value_counts())
# Out:
# False    159292
# dtype: int64

# %%
# вывести количество пустых строк
display(data.isnull().sum())
# Out:
# text     0
# toxic    0
# dtype: int64

# %% [markdown]
#  - Выполним токенизацию и лематтизацию данных.

# %% [markdown]
# ###### spaCy лемматизация

# %%
def clean_text(text):
    clean = nlp(" ".join(re.sub(r'[^a-zA-z]', ' ', text).split()))
    lemmatized_output = ' '.join([w.lemma_ for w in clean])
    return lemmatized_output

# %%
data['spacy_lemmatize'] = data['text'].parallel_apply(clean_text)

# %% [markdown]
#  - Удалим лишние столбцы.

# %%
data = data.drop(['text'], axis=1)

# %% [markdown]
# - Выведем общую информацию после предобработки данных.

# %%
get_data_info(data)
# Out:
#         toxic                                    spacy_lemmatize
# 148044      0  how have I harm those page you be waste my tim...
# 103729      0  the t and the h be more or less silent give sk...
# 15117       0  you list feminism as the prominent advocate ag...
# 80449       0  unfortunately not it s the same questionable r...
# 122591      0  that s an interesting point actually I m not t...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159292 entries, 0 to 159450
# Data columns (total 2 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   toxic            159292 non-null  int64
#  1   spacy_lemmatize  159292 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 3.6+ MB
# None

# %% [markdown]
# ### Создаем облако слов

# %%
data_words = data.copy()

# %%
text = ' '.join(data_words['spacy_lemmatize'])

# %%
FIG_SIZE = (17, 13)

# %% [markdown]
#  - используем `imshow`

# %%
# Generate the word cloud
cloud = WordCloud().generate(text)

# Plot the word cloud
plt.figure(figsize=FIG_SIZE)
plt.imshow(cloud, interpolation='bilinear', cmap='coolwarm')
plt.axis('off')
plt.title('Word Cloud of Text Data', fontsize=20)
plt.show()

# Save the plot to a file
plt.savefig('word_cloud.png', dpi=300, bbox_inches='tight')

# %% [markdown]
#  - используем `matshow`

# %%
# Generate the matrix data
cloud = WordCloud().generate(text)

# Plot the matrix
fig, ax = plt.subplots(figsize=FIG_SIZE)
ax.matshow(cloud, interpolation='bilinear', cmap='coolwarm')
ax.set_title('Matrix Plot of Text Data', fontsize=20)
plt.axis('off')
plt.show()

# Save the plot to a file
fig.savefig('matrix_plot.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Частотный анализ текста

# %%
type(text)
# Out:
# str

# %%
len(text)
# Out:
# 57483708

# %%
# перевод в единый нижний регистр
text = text.lower()

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
type(string.punctuation)
# Out:
# str

# %%
spec_chars = string.punctuation + '\n\xa0«»\t—…'

# %%
text = "".join([ch for ch in text if ch not in spec_chars])

# %%
text = re.sub('\n', '', text)

# %%
def remove_chars_from_text(text, chars):
    return "".join([ch for ch in text if ch not in chars])

# %%
text = remove_chars_from_text(text, spec_chars)

# %%
text = remove_chars_from_text(text, string.digits)

# %%
# Токенизация текста
text_tokens = word_tokenize(text)

# %%
print(type(text_tokens), len(text_tokens))
text_tokens[:10]
# Out:
# <class 'list'> 10843917
# ['explanation',
#  'why',
#  'the',
#  'edit',
#  'make',
#  'under',
#  'my',
#  'username',
#  'hardcore',
#  'metallica']

# %%
text = nltk.Text(text_tokens)
print(type(text))
text[:10]
# Out:
# <class 'nltk.text.Text'>
# ['explanation',
#  'why',
#  'the',
#  'edit',
#  'make',
#  'under',
#  'my',
#  'username',
#  'hardcore',
#  'metallica']

# %%
# Расчёт частоты встречаемости слов
fdist = FreqDist(text)
fdist
# Out:
# FreqDist({'the': 495736, 'be': 458567, 'to': 297478, 'i': 278853, 'of': 224030, 'and': 223449, 'you': 218399, 'a': 216854, 'that': 161241, 'it': 148272, ...})

# %%
fdist.most_common(5)
# Out:
# [('the', 495736),
#  ('be', 458567),
#  ('to', 297478),
#  ('i', 278853),
#  ('of', 224030)]

# %%
# Частотный график слов до очистки данных
plt.figure(figsize=(15, 7))
fdist.plot(30, cumulative=False)
plt.show()

# %%
from nltk.corpus import stopwords

# Now you can use the stopwords module
english_stopwords = stopwords.words("english")

# You can also remove stopwords from text using these stopwords

# %%
# Удаление стоп-словa
english_stopwords = stopwords.words("english")

# %%
print(len(english_stopwords))
# Out:
# 179

# %%
text_tokens = [token.strip()
               for token in text_tokens if token not in english_stopwords]

# %%
print(len(text_tokens))
# Out:
# 5488673

# %%
text = nltk.Text(text_tokens)

# %%
fdist_sw = FreqDist(text)
fdist_sw.most_common(10)
# Out:
# [('article', 72923),
#  ('page', 56856),
#  ('wikipedia', 48346),
#  ('talk', 39694),
#  ('edit', 37120),
#  ('use', 33013),
#  ('one', 30624),
#  ('make', 30371),
#  ('please', 29771),
#  ('would', 29336)]

# %%
# Частотный график слов после очистки данных
plt.figure(figsize=(15, 7))
fdist_sw.plot(30, cumulative=False)
plt.show()

# %% [markdown]
# Объявим переменные:
# - features_* — запишем в неё признаки;
# - target_* — запишем в неё целевой признак.
#
# Разобьем данные на три выборки:
#  1. " *_train " - обучающая (для обучения);
#  1. " *_valid " - валидационная (для поверки модели на переобучение);
#  1. " *_test " - тесстовая (для тестирования качества модели);
#  1. " *_train_valid " - обучающая+валидационная (для применения Cross-validation)
#
# Соотношение выборок по размеру данных будет следующим:
# - *_train : *_valid : *_test = 3:1:1

# %%
target = data['toxic']

features = data['spacy_lemmatize']

# %%
stop_words = set(stopwords.words('english'))

# %%
features_train, features_valid_test, target_train, target_valid_test = train_test_split(features,
                                                                                        target,
                                                                                        test_size=0.4,
                                                                                        random_state=12345,
                                                                                        stratify=target
                                                                                        )

features_valid, features_test, target_valid, target_test = train_test_split(features_valid_test,
                                                                            target_valid_test,
                                                                            test_size=0.5,
                                                                            random_state=12345,
                                                                            stratify=target_valid_test
                                                                            )

# %%
CV_COUNTS = 3

# %%
features_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 95575 entries, 129844 to 11556
# Series name: spacy_lemmatize
# Non-Null Count  Dtype
# --------------  -----
# 95575 non-null  object
# dtypes: object(1)
# memory usage: 1.5+ MB

# %%
print(features_train.shape)
print(features_valid.shape)
print(features_test.shape)
print()
print(target_train.shape)
print(target_valid.shape)
print(target_test.shape)
# Out:
# (95575,)
# (31858,)
# (31859,)
#
# (95575,)
# (31858,)
# (31859,)

# %% [markdown]
# ## Обучение

# %% [markdown]
# Обучим и подберем лучшие гиперпараметры для следующих методов:
#  - LogisticRegression (Pipeline + GridSearchCV);
#  - RidgeClassifier (Pipeline + GridSearchCV);
#  - SGDClassifier (Pipeline + GridSearchCV);
#  - LGBMClassifier (Pipeline + GridSearchCV).

# %% [markdown]
# ### LogisticRegression (Pipeline + GridSearchCV)

# %%
np.random.seed(42)

# %%
# Применили:
# TfidfVectorizer()

params = {'model__C': np.logspace(.5, 5, 10, 15),
          'model__class_weight': ['balanced', None]
          }

tfidf_vectorizer = TfidfVectorizer(stop_words=stop_words,
                                   ngram_range=(1, 2)
                                   )

pipeline = Pipeline([('tfidf_vectorizer', tfidf_vectorizer),
                     ('model', LogisticRegression(random_state=42))
                     ]
                    )

grid_LR = GridSearchCV(pipeline,
                       n_jobs=-1,
                       param_grid=params,
                       cv=CV_COUNTS,
                       scoring='f1'
                       )

grid_LR.fit(features_train, target_train)
print("Best parameters set found on development set:")
print()
print(grid_LR.best_params_)
print()
cv_F1_LR = grid_LR.best_score_
print('best_score F1:', round(cv_F1_LR, 2))
# Out:
# /Users/anaconda/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/anaconda/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ### RidgeClassifier (Pipeline + GridSearchCV)

# %%
params = {'model__alpha': [0.05, 0.1, 0.2, 0.4, 1]}

pipeline = Pipeline([('tfidf_vectorizer', TfidfVectorizer(stop_words=stop_words,
                                                          ngram_range=(1, 2))),
                     ('model', RidgeClassifier(random_state=42))
                     ]
                    )

grid_RC = GridSearchCV(pipeline,
                       n_jobs=-1,
                       param_grid=params,
                       cv=CV_COUNTS,
                       scoring='f1'
                       )

grid_RC.fit(features_train, target_train)
print("Best parameters set found on development set:")
print()
print(grid_RC.best_params_)
print()
cv_F1_RC = grid_RC.best_score_
print('best_score F1:', round(cv_F1_RC, 2))
# Out:
# Best parameters set found on development set:
#
# {'model__alpha': 0.4}
#
# best_score F1: 0.74

# %% [markdown]
# ### SGDClassifier (Pipeline + GridSearchCV)

# %%
params = {'model_SGDC__max_iter': np.arange(2, 100, 10)}


pipeline = Pipeline([('tfidf_vectorizer', TfidfVectorizer(stop_words=stop_words,
                                                          ngram_range=(1, 2))),
                     ('model_SGDC', SGDClassifier(random_state=42))
                     ]
                    )

grid_SGDC = GridSearchCV(pipeline,
                         n_jobs=-1,
                         param_grid=params,
                         cv=CV_COUNTS,
                         scoring='f1'
                         )

grid_SGDC.fit(features_train, target_train)
print("Best parameters set found on development set:")
print()
print(grid_SGDC.best_params_)
print()
cv_F1_SGDC = grid_SGDC.best_score_
print('best_score F1:', round(cv_F1_SGDC, 2))
# Out:
# /Users/anaconda/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/anaconda/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Users/anaconda/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:705: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# Best parameters set found on development set:
#
# {'model_SGDC__max_iter': 12}
#
# best_score F1: 0.59

# %% [markdown]
# ### LGBMClassifier (Pipeline + GridSearchCV)

# %%
grid_params = {'model_LGBM__max_depth': np.arange(10, 200, 100),
               'model_LGBM__reg_alpha': np.linspace(0, 1)
               }

pipe_LGBM = Pipeline(steps=[('tfidf', TfidfVectorizer(stop_words=stop_words,
                                                      ngram_range=(1, 1))),
                            ('model_LGBM', LGBMClassifier(random_state=42))
                            ]
                     )

print('# Tuning hyper-parameters for F1')
print()
clf_LGBM = GridSearchCV(estimator=pipe_LGBM,
                        param_grid=grid_params,
                        n_jobs=-1,
                        cv=CV_COUNTS,
                        scoring='f1')

clf_LGBM.fit(features_train, target_train)
print("Best parameters set found on development set:")
print()
print(clf_LGBM.best_params_)
print()
cv_F1_LGBM = clf_LGBM.best_score_
print('best_score F1:', round(cv_F1_LGBM, 2))
# Out:
# # Tuning hyper-parameters for F1
#
# Best parameters set found on development set:
#
# {'model_LGBM__max_depth': 110, 'model_LGBM__reg_alpha': 0.1020408163265306}
#
# best_score F1: 0.75

# %% [markdown]
#  - Построим сводный график ROС-кривых

# %%
plt.figure(figsize=[12, 9])

plt.plot([0, 1], [0, 1], linestyle='--', label='RandomModel')

probabilities_valid = grid_LR.best_estimator_.predict(features_valid)
probabilities_one_valid = probabilities_valid
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid)
auc_roc_LR = roc_auc_score(target_valid, probabilities_one_valid)
F1_LR = f1_score(target_valid, grid_LR.predict(features_valid))
plt.plot(fpr, tpr, label='LogisticRegression (Pipeline + GridSearchCV)')

probabilities_valid = grid_RC.best_estimator_.predict(features_valid)
probabilities_one_valid = probabilities_valid
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid)
auc_roc_RC = roc_auc_score(target_valid, probabilities_one_valid)
F1_RC = f1_score(target_valid, grid_RC.predict(features_valid))
plt.plot(fpr, tpr, label='RidgeClassifier (Pipeline + GridSearchCV)')

probabilities_valid = grid_SGDC.best_estimator_.predict(features_valid)
probabilities_one_valid = probabilities_valid
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid)
auc_roc_SGDC = roc_auc_score(target_valid, probabilities_one_valid)
F1_SGDC = f1_score(target_valid, grid_SGDC.predict(features_valid))
plt.plot(fpr, tpr, label='SGDClassifier (Pipeline + GridSearchCV)')

probabilities_valid = clf_LGBM.best_estimator_.predict(features_valid)
probabilities_one_valid = probabilities_valid
fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one_valid)
auc_roc_LGBMC = roc_auc_score(target_valid, probabilities_one_valid)
F1_LGBM = f1_score(target_valid, clf_LGBM.predict(features_valid))
plt.plot(fpr, tpr, label='LGBMClassifier (Pipeline + GridSearchCV)')

plt.xlim([0, 1])
plt.ylim([0, 1])

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.legend(loc='lower right', fontsize='x-large')

plt.title("ROC-кривая")
plt.show()

# %% [markdown]
# - Построим сводную таблицу: F1 и AUC-ROC.

# %%
index = ['LogisticRegression (Pipeline + GridSearchCV)',
         'RidgeClassifier (Pipeline + GridSearchCV)',
         'SGDClassifier (Pipeline + GridSearchCV)',
         'LGBMClassifier (Pipeline + GridSearchCV)'
         ]

data = {'F1 на CV': [round(F1_LR, 2),
                     round(F1_RC, 2),
                     round(F1_SGDC, 2),
                     round(F1_LGBM, 2)
                     ],

        'AUC-ROC': [round(auc_roc_LR, 2),
                    round(auc_roc_RC, 2),
                    round(auc_roc_SGDC, 2),
                    round(auc_roc_LGBMC, 2)
                    ]
        }

scores_data = pd.DataFrame(data=data, index=index)
scores_data
# Out:
#                                               F1 на CV  AUC-ROC
# LogisticRegression (Pipeline + GridSearchCV)      0.80     0.88
# RidgeClassifier (Pipeline + GridSearchCV)         0.75     0.82
# SGDClassifier (Pipeline + GridSearchCV)           0.57     0.70
# LGBMClassifier (Pipeline + GridSearchCV)          0.75     0.82

# %% [markdown]
# ###### Выводы:
# На валидационной выборке мы получили следующие результаты:
#
# - F1:
#  - LogisticRegression (Pipeline + GridSearchCV) = 0.80;
#  - RidgeClassifier (Pipeline + GridSearchCV) = 0.75;
#  - SGDClassifier (Pipeline + GridSearchCV) = 0.57;
#  - LGBMClassifier (Pipeline + GridSearchCV) = 0.75.
#
#
# - AUC-ROC:
#  - LogisticRegression (Pipeline + GridSearchCV) = 0.89;
#  - RidgeClassifier (Pipeline + GridSearchCV) = 0.82;
#  - SGDClassifier (Pipeline + GridSearchCV) = 0.70;
#  - LGBMClassifier (Pipeline + GridSearchCV) = 0.82.
#
#
# - Модели LogisticRegression (Pipeline + GridSearchCV), RidgeClassifier (Pipeline + GridSearchCV) и LGBMClassifier (Pipeline + GridSearchCV) показали значения F1 >= 0.75.
#
#
# - Самые лучшие показатели F1 и AUC-ROC в совокупности были у модели: LogisticRegression (Pipeline + GridSearchCV). Именно эту модель мы рекомендуем для выполнения поставленной задачи. На следующем шаге протестируем данную модель на тестовой выборке.

# %% [markdown]
# ## Выводы

# %% [markdown]
# - Проверим на тестовой выборке выше тестируемые модели, у которых значение  F1 >= 0.75:
#  - LogisticRegression (Pipeline + GridSearchCV)
#  - RidgeClassifier (Pipeline + GridSearchCV)
#  - LGBMClassifier (Pipeline + GridSearchCV)

# %%
plt.figure(figsize=[12, 9])

plt.plot([0, 1], [0, 1], linestyle='--', label='RandomModel')

probabilities_test = grid_LR.best_estimator_.predict(features_test)
probabilities_one_test = probabilities_test
fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test)
auc_roc_LR_test = roc_auc_score(target_test, probabilities_one_test)
F1_LR_test = f1_score(target_test, grid_LR.predict(features_test))
plt.plot(fpr, tpr, label='LogisticRegression_test')

probabilities_test = grid_LR.best_estimator_.predict(features_test)
probabilities_one_test = probabilities_test
fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test)
auc_roc_RC_test = roc_auc_score(target_test, probabilities_one_test)
F1_RC_test = f1_score(target_test, grid_RC.predict(features_test))
plt.plot(fpr, tpr, label='RidgeClassifier_test')

probabilities_test = grid_LR.best_estimator_.predict(features_test)
probabilities_one_test = probabilities_test
fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test)
auc_roc_LGBMC_test = roc_auc_score(target_test, probabilities_one_test)
F1_LGBM_test = f1_score(target_test, clf_LGBM.predict(features_test))
plt.plot(fpr, tpr, label='LGBMClassifier_test')

plt.xlim([0, 1])
plt.ylim([0, 1])

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.legend(loc='lower right', fontsize='x-large')

plt.title("ROC-кривая")
plt.show()

# %%
index = ['LogisticRegression_test',
         'RidgeClassifier_test',
         'LGBMClassifier_test'
         ]

data = {'F1 на CV': [round(F1_LR_test, 2),
                     round(F1_RC_test, 2),
                     round(F1_LGBM_test, 2)
                     ],

        'AUC-ROC': [round(auc_roc_LR_test, 2),
                    round(auc_roc_RC_test, 2),
                    round(auc_roc_LGBMC_test, 2)
                    ]
        }

scores_data = pd.DataFrame(data=data, index=index)
scores_data
# Out:
#                          F1 на CV  AUC-ROC
# LogisticRegression_test      0.78     0.87
# RidgeClassifier_test         0.74     0.87
# LGBMClassifier_test          0.74     0.87

# %% [markdown]
# ###### Выводы:
# На тестовой выборке мы получили следующие результаты:
#
# - F1:
#  - LogisticRegression_test = 0.78;
#  - RidgeClassifier_test = 0.74;
#  - LGBMClassifier_test = 0.74.
#
#
# - AUC-ROC:
#  - LogisticRegression (Pipeline + GridSearchCV) = 0.87;
#  - RidgeClassifier (Pipeline + GridSearchCV) = 0.87;
#  - LGBMClassifier (Pipeline + GridSearchCV) = 0.87.
#
#
# - Только модель LogisticRegression_test показала значения F1 >= 0.75
#
#
# - Таким образом только модель LogisticRegression мы можем рекомендовать для выполнения поставленной задачи.

# %% [markdown]
# # Отчет:
#
#
# ## Проект для «Викишоп»
#
# - Интернет-магазин «Викишоп» запускает новый сервис. Теперь пользователи могут редактировать и дополнять описания товаров, как в вики-сообществах. То есть клиенты предлагают свои правки и комментируют изменения других. Магазину нужен инструмент, который будет искать токсичные комментарии и отправлять их на модерацию.
#
# #### Нами были выполнены следующие этапы исследования:
#
# 1. Общий обзор данных (выведение общей информации и примера данных);
# 2. Провести предобработку данных (изучить данные; заполнить пропущенные значения и обработать аномалии в столбцах; если среди признаков имеются неинформативные, то удалить их);
# 3. Подготовить выборки для обучения моделей;
# 4. Анализ данных (непосредственно на данном этапе мы выполняли поставленные нами задачи);
# 5. Вывод и заключение.
#
# #### Нами были выполнены все условия:
#  - Построить модель со значением метрики качества F1 не меньше 0.75.
#
# #### В результате исследования мы смогли сделать следующие выводы:
# При анализе данных мы использовали следующие модели и получили соответствующие результаты:
#
# 1. F1:
#  - LogisticRegression (Pipeline + GridSearchCV) = 0.80;
#  - RidgeClassifier (Pipeline + GridSearchCV) = 0.75;
#  - SGDClassifier (Pipeline + GridSearchCV) = 0.57;
#  - LGBMClassifier (Pipeline + GridSearchCV) = 0.75.
#
#
# 2. AUC-ROC:
#  - LogisticRegression (Pipeline + GridSearchCV) = 0.89;
#  - RidgeClassifier (Pipeline + GridSearchCV) = 0.82;
#  - SGDClassifier (Pipeline + GridSearchCV) = 0.70;
#  - LGBMClassifier (Pipeline + GridSearchCV) = 0.82.
#
# 3. - Модели LogisticRegression (Pipeline + GridSearchCV), RidgeClassifier (Pipeline + GridSearchCV) и LGBMClassifier (Pipeline + GridSearchCV) показали значения F1 >= 0.75.
#
# 4. Самые лучшие показатели F1 и AUC-ROC в совокупности были у модели: LogisticRegression. Именно эту модель мы рекомендуем для выполнения поставленной задачи.
#
# 5. На тестовой выборке модель LogisticRegression показала следущие результаты:
#  - F1 = 0.78;
#  - AUC-ROC = 0.87
#
# По ходу выполнения всех этапов проекта мы делали промежуточные выводы, которые помогли нам сделать конечные выводы.
