# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc">
#   <ul class="toc-item">
#     <li><span><a href="#Проект:-Прототип-модели-машинного-обучения-для-«Оператора-связи-&quot;Ниединогоразрыва.ком&quot;»." data-toc-modified-id="Проект:-Прототип-модели-машинного-обучения-для-«Оператора-связи-&quot;Ниединогоразрыва.ком&quot;».-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Проект: Прототип модели машинного обучения для «Оператора связи "Ниединогоразрыва.ком"».</a></span>
#       <ul class="toc-item">
#         <li><span><a href="#Описание-услуг" data-toc-modified-id="Описание-услуг-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание услуг</a></span>
#           <ul class="toc-item">
#             <li><ul class="toc-item">
#                 <li><span><a href="#Цель:-Построить-модель-для-прогнозирования-оттока-клиентов." data-toc-modified-id="Цель:-Построить-модель-для-прогнозирования-оттока-клиентов.-1.1.0.1"><span class="toc-item-num">1.1.0.1&nbsp;&nbsp;</span>Цель: Построить модель для прогнозирования оттока клиентов.</a></span></li>
#                 <li><span><a href="#Условия:" data-toc-modified-id="Условия:-1.1.0.2"><span class="toc-item-num">1.1.0.2&nbsp;&nbsp;</span>Условия:</a></span></li>
#                 <li><span><a href="#Задачи:" data-toc-modified-id="Задачи:-1.1.0.3"><span class="toc-item-num">1.1.0.3&nbsp;&nbsp;</span>Задачи:</a></span></li>
#                 <li><span><a href="#Этапы-исследования:" data-toc-modified-id="Этапы-исследования:-1.1.0.4"><span class="toc-item-num">1.1.0.4&nbsp;&nbsp;</span>Этапы исследования:</a></span></li>
#             </ul></li>
#           </ul>
#         </li>
#         <li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span>
#           <ul class="toc-item">
#             <li><span><a href="#Обозначения-признаков" data-toc-modified-id="Обозначения-признаков-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Обозначения признаков</a></span></li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#     <li><span><a href="#Подготовка,-исследовательский-анализ,-предобработка-данных." data-toc-modified-id="Подготовка,-исследовательский-анализ,-предобработка-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка, исследовательский анализ, предобработка данных.</a></span>
#       <ul class="toc-item">
#         <li><ul class="toc-item">
#           <li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Выводы:</a></span>
#             <ul class="toc-item">
#               <li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-2.0.1.1"><span class="toc-item-num">2.0.1.1&nbsp;&nbsp;</span>Вывод:</a></span></li>
#             </ul>
#           </li>
#         </ul></li>
#       </ul>
#     </li>
#     <li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span></li>
#     <li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение моделей</a></span>
#       <ul class="toc-item">
#         <li><ul class="toc-item">
#           <li><span><a href="#RandomForestClassifier-(GridSearchCV)" data-toc-modified-id="RandomForestClassifier-(GridSearchCV)-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>RandomForestClassifier (GridSearchCV)</a></span></li>
#           <li><span><a href="#CatBoost-[закодированные-признаки]-(GridSearchCV)" data-toc-modified-id="CatBoost-[закодированные-признаки]-(GridSearchCV)-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>CatBoost [закодированные признаки] (GridSearchCV)</a></span></li>
#           <li><span><a href="#LightGBMClassifier-(GridSearchCV)" data-toc-modified-id="LightGBMClassifier-(GridSearchCV)-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>LightGBMClassifier (GridSearchCV)</a></span></li>
#         </ul></li>
#         <li><span><a href="#Проверим-наилучшие-параметры-лучшей-модели-на-тестовой-выборке." data-toc-modified-id="Проверим-наилучшие-параметры-лучшей-модели-на-тестовой-выборке.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Проверим наилучшие параметры лучшей модели на тестовой выборке.</a></span>
#           <ul class="toc-item">
#             <li><span><a href="#CatBoostClassifier" data-toc-modified-id="CatBoostClassifier-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>CatBoostClassifier</a></span>
#               <ul class="toc-item">
#                 <li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.1.1.1"><span class="toc-item-num">4.1.1.1&nbsp;&nbsp;</span>Вывод:</a></span></li>
#               </ul>
#             </li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#     <li><span><a href="#Проект:-Прототип-модели-машинного-обучения-для-«Оператора-связи-&quot;Ниединогоразрыва.ком&quot;»." data-toc-modified-id="Проект:-Прототип-модели-машинного-обучения-для-«Оператора-связи-&quot;Ниединогоразрыва.ком&quot;».-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проект: Прототип модели машинного обучения для «Оператора связи "Ниединогоразрыва.ком"».</a></span>
#       <ul class="toc-item">
#         <li><span><a href="#Описание-услуг" data-toc-modified-id="Описание-услуг-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Описание услуг</a></span>
#           <ul class="toc-item">
#             <li><span><a href="#Нами-были-выполнены-следующие-этапы-исследования:" data-toc-modified-id="Нами-были-выполнены-следующие-этапы-исследования:-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Нами были выполнены следующие этапы исследования:</a></span></li>
#             <li><span><a href="#Нами-были-выполнены-все-условия:" data-toc-modified-id="Нами-были-выполнены-все-условия:-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Нами были выполнены все условия:</a></span></li>
#             <li><span><a href="#В-результате-исследования-мы-смогли-сделать-следующие-выводы:" data-toc-modified-id="В-результате-исследования-мы-смогли-сделать-следующие-выводы:-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>В результате исследования мы смогли сделать следующие выводы:</a></span></li>
#             <li><span><a href="#Заключение:" data-toc-modified-id="Заключение:-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Заключение:</a></span></li>
#           </ul>
#         </li>
#       </ul>
#     </li>
#   </ul>
# </div>

# %% [markdown]
# # Проект: Прототип модели машинного обучения для «Оператора связи "Ниединогоразрыва.ком"».
#
# - Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.
#
# ### Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 1. Интернет. Подключение может быть двух типов: через телефонную линию (DSL*,* от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*).
#
# Также доступны такие услуги:
#
# 1. Интернет-безопасность: антивирус (*DeviceProtection*) и блокировка небезопасных сайтов (*OnlineSecurity*);
# 1. Выделенная линия технической поддержки (*TechSupport*);
# 1. Облачное хранилище файлов для резервного копирования данных (*OnlineBackup*);
# 1. Стриминговое телевидение (*StreamingTV*) и каталог фильмов (*StreamingMovies*).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.
#
#
# ## План проекта:
#
# ##### Цель:
# Построить модель для прогнозирования оттока клиентов.
#
# ##### Условия:
#  - Использовать бизнес-метрики:
#   1. Основная метрика: AUC-ROC (метрика, которая учитывает возможность балансировать между false posititve и false negative.); целевое значение AUC-ROC >= 0.85
#   1. Дополнительная метрика: Accuracy;
#  - Использовать значение RANDOM_STATE = 100423;
#  - Размер тестовой выборки: test_size = 0.25;
#  - Проверить корреляцию числовых признаков на наличие мультиколлинеарности;
#  - Должны быть рассмотрены как минимум две (а лучше три) модели машинного обучения, например случайный лес и градиентный бустинг. При использовании только двух моделей нельзя использовать две вариации градиентного бустинга.
#
# ##### Задачи:
# 1. На тренировочной выборке обучить разные модели, одна из которых — бустинг (LightGBM, Catboost), и как минимум одна — не бустинг (RandomForest); для каждой модели попробовать разные гиперпараметры;
# 1. Проанализировать AUC-ROC и Accuracy моделей;
# 1. Опираясь на критерии заказчика, выбрать лучшую модель, проверить её качество на тестовой выборке.
#
# ##### Этапы исследования:
# 1. Общий обзор данных (выведение общей информации, корректировка названия столбов при необходимости, выведение примера таблицы);
# 2. Провести предобработку данных (поиск дубликатов, анализ пропусков, объединение датасетов, выявление `target` и `features`);
# 3. Анализ данных (непосредственно на данном этапе мы будем выполнять поставленные нами задачи);
# 4. Вывод и заключение.
#
# По ходу выполнения всех этапов проекта мы будем делать промежуточные выводы, которые помогут нам сделать конечные выводы.
#
# ### Описание данных
#
# Данные состоят из файлов, полученных из разных источников:
#
# - `contract_new.csv` — информация о договоре;
# - `personal_new.csv` — персональные данные клиента;
# - `internet_new.csv` — информация об интернет-услугах;
# - `phone_new.csv` — информация об услугах телефонии.
#
# Во всех файлах столбец `customerID` содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.
#
# #### Обозначения признаков
#
# 1. BeginDate – дата начала пользования услугами;
# 1. EndDate – дата окончания пользования услугами;
# 1. Type – тип оплаты: ежемесячный, годовой и тд;
# 1. PaperlessBilling – безналичный расчет;
# 1. PaymentMethod – способ оплаты;
# 1. MonthlyCharges – ежемесячные траты на услуги;
# 1. TotalCharges – всего потрачено денег на услуги;
# 1. Dependents – наличие иждивенцев;
# 1. Senior Citizen – наличие пенсионного статуса по возрасту;
# 1. Partner – наличие супруга(и);
# 1. MultipleLines – наличие возможности ведения параллельных линий во время звонка.

# %% [markdown]
# ## Подготовка, исследовательский анализ, предобработка данных.

# %%
import phik
import pandas_profiling
from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler
)
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    cross_val_score,
    cross_val_predict
)
from sklearn.metrics import (
    roc_auc_score,
    accuracy_score,
    roc_curve
)
from catboost import cv, CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
import copy
import datetime
import random
import time
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import sweetviz as sv

from IPython.display import display

from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
df_contract = pd.read_csv(
    '/Users/kolotukhin.md/Downloads/jupyter_notebook/14/final_provider/contract_new.csv')
df_personal = pd.read_csv(
    '/Users/kolotukhin.md/Downloads/jupyter_notebook/14/final_provider/personal_new.csv')
df_internet = pd.read_csv(
    '/Users/kolotukhin.md/Downloads/jupyter_notebook/14/final_provider/internet_new.csv')
df_phone = pd.read_csv(
    '/Users/kolotukhin.md/Downloads/jupyter_notebook/14/final_provider/phone_new.csv')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# - С помощью `sweetviz` создадим сводный отчет по каждому из датасетов.

# %%
# report = sv.analyze([df_contract, "Info_df_contract_1.0"])

# %%
# report = sv.analyze([df_personal, "Info_df_personal_1.0"])

# %%
# report = sv.analyze([df_internet, "Info_df_internet_1.0"])

# %%
# report = sv.analyze([df_phone, "Info_df_phone_1.0"])

# %% [markdown]
# - Выведем сводную информацию о таблице и выведем первые 10 строк таблицы

# %%
df_list = [df_contract, df_personal, df_internet, df_phone]
for i in df_list:
    display(i.head(10))
    print(i.info())
    print()
    print(i.shape)
    print()
    print(i.dtypes)
# Out:
#    customerID   BeginDate     EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01          No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01          No        One year               No
# 2  3668-QPYBK  2019-10-01          No  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01          No        One year               No
# 4  9237-HQITU  2019-09-01          No  Month-to-month              Yes
# 5  9305-CDSKC  2019-03-01          No  Month-to-month              Yes
# 6  1452-KIOVK  2018-04-01          No  Month-to-month              Yes
# 7  6713-OKOMC  2019-04-01          No  Month-to-month               No
# 8  7892-POOKP  2017-07-01          No  Month-to-month              Yes
# 9  6388-TABGU  2014-12-01  2017-05-01        One year               No
#
#                PaymentMethod  MonthlyCharges TotalCharges
# 0           Electronic check           29.85        31.04
# 1               Mailed check           56.95      2071.84
# ...

# %% [markdown]
# - Объединим датасеты

# %%
df_merge = pd.merge(df_contract, df_personal, how='left', on='customerID')
df_merge = pd.merge(df_merge, df_internet, how='left', on='customerID')
df_merge = pd.merge(df_merge, df_phone, how='left', on='customerID')

# %% [markdown]
# - Приведем название столбцов в стиль "snake_case" и в нижний регистр
# - Выведем сводную информацию о таблице
# - Выведем тип данных

# %%
df_merge.columns = df_merge.columns.str.replace(
    r"([A-Z])", r" \1").str.lower().str.replace(' ', '_').str[1:]

print(df_merge.shape)
print()

# вывести тип данных
print(df_merge.dtypes)
# Out:
# (7043, 20)
#
# ustomer_i_d           object
# begin_date            object
# end_date              object
# type                  object
# paperless_billing     object
# payment_method        object
# monthly_charges      float64
# total_charges         object
# ender                 object
# senior_citizen         int64
# partner               object
# dependents            object
# internet_service      object
# online_security       object
# online_backup         object
# device_protection     object
# tech_support          object
# streaming_t_v         object
# streaming_movies      object
# multiple_lines        object
# dtype: object
# /var/folders/mz/b2hbqf51521_fzm8c30chvf40000gn/T/ipykernel_21203/2417915822.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_merge.columns = df_merge.columns.str.replace(

# %% [markdown]
# - Переименуем столбец ustomer_i_d согласно правилам стиля Python

# %%
df_merge = df_merge.rename(columns={'ustomer_i_d': 'customer_id',
                                    'streaming_t_v': 'streaming_tv',
                                    'ender': 'gender'}
                           )

print(df_merge.dtypes)
# Out:
# customer_id           object
# begin_date            object
# end_date              object
# type                  object
# paperless_billing     object
# payment_method        object
# monthly_charges      float64
# total_charges         object
# gender                object
# senior_citizen         int64
# partner               object
# dependents            object
# internet_service      object
# online_security       object
# online_backup         object
# device_protection     object
# tech_support          object
# streaming_tv          object
# streaming_movies      object
# multiple_lines        object
# dtype: object

# %% [markdown]
# - Проверим на дубликаты

# %%
print(df_merge.duplicated().sum())
# Out:
# 0

# %% [markdown]
# - Выведем на экран информацию о пропусках в данных

# %%
pd.DataFrame(df_merge.isna().mean()
             .to_frame(name='Пропуски')
             .query('Пропуски > 0')['Пропуски'])\
    .style.background_gradient('coolwarm')\
    .format({'Пропуски': '{:.2%}'})
# Out:
# <style type="text/css">
# #T_bf6d7_row0_col0, #T_bf6d7_row1_col0, #T_bf6d7_row2_col0, #T_bf6d7_row3_col0, #T_bf6d7_row4_col0, #T_bf6d7_row5_col0, #T_bf6d7_row6_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bf6d7_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bf6d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf6d7_level0_col0" class="col_heading level0 col0" >Пропуски</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf6d7_level0_row0" class="row_heading level0 row0" >internet_service</th>
#       <td id="T_bf6d7_row0_col0" class="data row0 col0" >21.67%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6d7_level0_row1" class="row_heading level0 row1" >online_security</th>
#       <td id="T_bf6d7_row1_col0" class="data row1 col0" >21.67%</td>
#     </tr>
#     <tr>
#       <th id="T_bf6d7_level0_row2" class="row_heading level0 row2" >online_backup</th>
# ...

# %% [markdown]
# - Предположим, что пустые значения в объединенной таблице в тех ячейках, где значений нет. Другими словами присвоим этим ячейкам значения "No". И затем снова проверим наши данные на пропуски.

# %%
df_merge = df_merge.fillna('No')

# %% [markdown]
# - Выведем на экран информацию о пропусках в данных после проведенной обработки

# %%
pd.DataFrame(df_merge.isna().mean()
             .to_frame(name='Пропуски')
             .query('Пропуски > 0')['Пропуски'])\
    .style.background_gradient('coolwarm')\
    .format({'Пропуски': '{:.2%}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_29d9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29d9f_level0_col0" class="col_heading level0 col0" >Пропуски</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# - Выведем 10 строк объединенной таблицы

# %%
display(df_merge.head(10))
# Out:
#   customer_id  begin_date    end_date            type paperless_billing  \
# 0  7590-VHVEG  2020-01-01          No  Month-to-month               Yes
# 1  5575-GNVDE  2017-04-01          No        One year                No
# 2  3668-QPYBK  2019-10-01          No  Month-to-month               Yes
# 3  7795-CFOCW  2016-05-01          No        One year                No
# 4  9237-HQITU  2019-09-01          No  Month-to-month               Yes
# 5  9305-CDSKC  2019-03-01          No  Month-to-month               Yes
# 6  1452-KIOVK  2018-04-01          No  Month-to-month               Yes
# 7  6713-OKOMC  2019-04-01          No  Month-to-month                No
# 8  7892-POOKP  2017-07-01          No  Month-to-month               Yes
# 9  6388-TABGU  2014-12-01  2017-05-01        One year                No
#
#               payment_method  monthly_charges total_charges  gender  \
# 0           Electronic check            29.85         31.04  Female
# ...

# %% [markdown]
# - Создадим новый признак "exited". Если на 1 февраля 2020 клиент не закончил свое сотрудничество с компанией, тогда придаем значение "0". Если же клиент прекратил сотрудничество с компанией, тогда придаем значение "1".

# %%
df_merge['exited'] = df_merge['end_date'].apply(
    lambda x: 0 if x == 'No' else 1)

# %% [markdown]
# - Заменим значения "No" в столбце "end_date" на актуальную дату на момент проведения нашего исследования "1 февраля 2020". Чтобы затем вычислить в месяцах длительность сотрудничества клиентов с компанией на текущий момент.

# %%
df_merge['end_date'] = df_merge['end_date'].replace('No', '2020-02-01')

# %%
df_merge['end_date'] = pd.to_datetime(df_merge['end_date'])
df_merge['begin_date'] = pd.to_datetime(df_merge['begin_date'])
df_merge['duration'] = (
    (df_merge['end_date'] - df_merge['begin_date']) / np.timedelta64(1, 'D')).round()
df_merge['duration'] = df_merge['duration'].astype(int)

# %% [markdown]
# - Удалим столбцы, не несущие смысловой нагрузки для дальнейшего анализа.

# %%
df_merge = df_merge.drop(columns=['begin_date',
                                  'end_date']
                         )

# %% [markdown]
# - Сделаем индексацию таблицы по столбцу 'customer_id'

# %%
df_merge = df_merge.set_index('customer_id')

# %% [markdown]
# - Выведем сводную информацию

# %%
display(df_merge.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               7043 non-null   object
#  1   paperless_billing  7043 non-null   object
#  2   payment_method     7043 non-null   object
#  3   monthly_charges    7043 non-null   float64
#  4   total_charges      7043 non-null   object
#  5   gender             7043 non-null   object
#  6   senior_citizen     7043 non-null   int64
#  7   partner            7043 non-null   object
#  8   dependents         7043 non-null   object
#  9   internet_service   7043 non-null   object
#  10  online_security    7043 non-null   object
#  11  online_backup      7043 non-null   object
#  12  device_protection  7043 non-null   object
#  13  tech_support       7043 non-null   object
#  14  streaming_tv       7043 non-null   object
# ...

# %% [markdown]
# - Выведем 10 строк объединенной таблицы после обработки данных

# %%
display(df_merge.head(10))
# Out:
#                        type paperless_billing             payment_method  \
# customer_id
# 7590-VHVEG   Month-to-month               Yes           Electronic check
# 5575-GNVDE         One year                No               Mailed check
# 3668-QPYBK   Month-to-month               Yes               Mailed check
# 7795-CFOCW         One year                No  Bank transfer (automatic)
# 9237-HQITU   Month-to-month               Yes           Electronic check
# 9305-CDSKC   Month-to-month               Yes           Electronic check
# 1452-KIOVK   Month-to-month               Yes    Credit card (automatic)
# 6713-OKOMC   Month-to-month                No               Mailed check
# 7892-POOKP   Month-to-month               Yes           Electronic check
# 6388-TABGU         One year                No  Bank transfer (automatic)
#
#              monthly_charges total_charges  gender  senior_citizen partner  \
# customer_id
# ...

# %% [markdown]
# - Выведем уникальные значения каждого из столбцов с помощью функции

# %%
def unique_values(df):
    for column in df.columns:
        print(f"Unique values in {column}:")
        print(df_merge[column].unique())
        print("")


print(unique_values(df_merge))
# Out:
# Unique values in type:
# ['Month-to-month' 'One year' 'Two year']
#
# Unique values in paperless_billing:
# ['Yes' 'No']
#
# Unique values in payment_method:
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#
# Unique values in monthly_charges:
# [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
#
# Unique values in total_charges:
# ['31.04' '2071.84' '226.17' ... '325.6' '520.8' '7251.82']
#
# Unique values in gender:
# ['Female' 'Male']
#
# Unique values in senior_citizen:
# [0 1]
#
# Unique values in partner:
# ['Yes' 'No']
#
# Unique values in dependents:
# ['No' 'Yes']
#
# Unique values in internet_service:
# ['DSL' 'Fiber optic' 'No']
#
# Unique values in online_security:
# ['No' 'Yes']
#
# Unique values in online_backup:
# ['Yes' 'No']
#
# Unique values in device_protection:
# ['No' 'Yes']
#
# Unique values in tech_support:
# ['No' 'Yes']
#
# Unique values in streaming_tv:
# ['No' 'Yes']
#
# Unique values in streaming_movies:
# ...

# %% [markdown]
# - Выведем количество уникальных значений каждого из столбцов

# %%
unique_counts = df_merge.nunique()
print(unique_counts)
# Out:
# type                    3
# paperless_billing       2
# payment_method          4
# monthly_charges      1585
# total_charges        6658
# gender                  2
# senior_citizen          2
# partner                 2
# dependents              2
# internet_service        3
# online_security         2
# online_backup           2
# device_protection       2
# tech_support            2
# streaming_tv            2
# streaming_movies        2
# multiple_lines          2
# exited                  2
# duration              251
# dtype: int64

# %%
display(df_merge.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               7043 non-null   object
#  1   paperless_billing  7043 non-null   object
#  2   payment_method     7043 non-null   object
#  3   monthly_charges    7043 non-null   float64
#  4   total_charges      7043 non-null   object
#  5   gender             7043 non-null   object
#  6   senior_citizen     7043 non-null   int64
#  7   partner            7043 non-null   object
#  8   dependents         7043 non-null   object
#  9   internet_service   7043 non-null   object
#  10  online_security    7043 non-null   object
#  11  online_backup      7043 non-null   object
#  12  device_protection  7043 non-null   object
#  13  tech_support       7043 non-null   object
#  14  streaming_tv       7043 non-null   object
# ...

# %% [markdown]
# - Выведем список (отсортированный по возрастанию) уникальных значений столбца "total_charges", чтобы оценить наличие аномальных значений в этих столбцах и выяснить из-за чего у данного столбца тип данных: object.

# %%
unique_values_t_c = df_merge["total_charges"].unique()
unique_values_sorted_t_c = sorted(unique_values_t_c)
print(unique_values_sorted_t_c)
# Out:
# [' ', '100.17', '100.19', '100.2', '100.24', '100.25', '100.4', '100.75', '100.88', '100.9', '100.94', '1000.0', '1000.12', '1000.43', '1001.0', '1001.1', '1001.81', '1002.05', '1002.13', '1002.46', '1003.15', '1003.93', '1004.08', '1005.2', '1005.3', '1006.0', '1006.95', '1007.1', '1007.5', '1008.37', '1008.45', '1008.48', '1008.58', '1008.6', '1008.8', '1009.65', '1009.8', '101.0', '101.2', '101.25', '101.75', '1010.1', '1010.65', '1011.66', '1012.35', '1012.5', '1013.27', '1013.5', '1014.75', '1015.07', '1015.2', '1016.6', '1017.45', '1017.9', '1018.37', '1018.77', '1018.8', '1019.4', '102.01', '102.25', '102.38', '102.41', '102.61', '102.64', '102.75', '102.8', '1020.6', '1021.76', '1021.8', '1023.51', '1023.8', '1023.85', '1024.06', '1024.1', '1027.31', '1028.98', '1028.99', '103.25', '103.52', '103.55', '103.84', '1030.26', '1031.05', '1032.2', '1032.35', '1033.6', '1033.85', '1034.28', '1035.34', '1035.94', '1036.15', '1036.2', '1036.59', '1037.7', '1037.95', '1038.6', '1039.3
# ...

# %% [markdown]
# - Выведем на экран строки со значением столбца "total_charges" равным пробелу.

# %%
df_merge.query("total_charges == ' '")
# Out:
#                  type paperless_billing             payment_method  \
# customer_id
# 4472-LVYGI   Two year               Yes  Bank transfer (automatic)
# 3115-CZMZD   Two year                No               Mailed check
# 5709-LVOEQ   Two year                No               Mailed check
# 4367-NUYAO   Two year                No               Mailed check
# 1371-DWPAZ   Two year                No    Credit card (automatic)
# 7644-OMVMY   Two year                No               Mailed check
# 3213-VVOLG   Two year                No               Mailed check
# 2520-SGTTA   Two year                No               Mailed check
# 2923-ARZLG   One year               Yes               Mailed check
# 4075-WKNIU   Two year                No               Mailed check
# 2775-SEFEE   Two year               Yes  Bank transfer (automatic)
#
#              monthly_charges total_charges  gender  senior_citizen partner  \
# customer_id
# ...

# %% [markdown]
# - Мы вывели строки со значением столца "total_charges" равным пробелу. В этих строках значение столца "duration" равно нулю. Предположим, что тут есть прямая зависимость. Выведем количество строк с тем и другим значением, чтобы подтвердить наше предположение.

# %%
count_space = (df_merge['total_charges'] == " ").sum()
print(count_space)
# Out:
# 11

# %%
count_zero = (df_merge['duration'] == 0).sum()
print(count_zero)
# Out:
# 11

# %% [markdown]
# - Наше предположение оказалось верным. Количество строк с такими значениями очень маленькое. Поэтому их удаление не повлечет для нас серьезных последствий. Удалим строки с этими значениями.

# %%
df_merge = df_merge.drop(df_merge[df_merge['duration'] == 0].index)

# %%
# изменим тип данных на "float64", так как мы удалили пробелы.
df_merge['total_charges'] = df_merge['total_charges'].astype('float64')

# %%
# изменим тип данных на "object", так как это бинарный признак.
df_merge['senior_citizen'] = df_merge['senior_citizen'].astype('object')

# %%
# выведем общую информацию о датасете
display(df_merge.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               7032 non-null   object
#  1   paperless_billing  7032 non-null   object
#  2   payment_method     7032 non-null   object
#  3   monthly_charges    7032 non-null   float64
#  4   total_charges      7032 non-null   float64
#  5   gender             7032 non-null   object
#  6   senior_citizen     7032 non-null   object
#  7   partner            7032 non-null   object
#  8   dependents         7032 non-null   object
#  9   internet_service   7032 non-null   object
#  10  online_security    7032 non-null   object
#  11  online_backup      7032 non-null   object
#  12  device_protection  7032 non-null   object
#  13  tech_support       7032 non-null   object
#  14  streaming_tv       7032 non-null   object
# ...

# %%
df_numeric = df_merge[['monthly_charges',
                       'duration',
                       'total_charges']
                      ]

# %% [markdown]
# - Выведем статистические характеристики числовых признаков.

# %%
df_numeric.describe()
# Out:
#        monthly_charges     duration  total_charges
# count      7032.000000  7032.000000    7032.000000
# mean         64.798208   899.961320    2118.621822
# std          30.085974   682.738777    2112.736199
# min          18.250000    28.000000      19.050000
# 25%          35.587500   276.000000     439.745000
# 50%          70.350000   761.000000    1345.275000
# 75%          89.862500  1461.000000    3239.317500
# max         118.750000  2314.000000    9221.380000

# %% [markdown]
# - Построим гистограммы числовых признаков.

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, col in enumerate(df_numeric.columns):
    axs[i].hist(df_numeric[col], bins=20)
    axs[i].set_title(col)

# Увеличим размер шрифта названий графиков
for ax in axs:
    ax.title.set_fontsize(18)

plt.tight_layout()
plt.show()
plt.close()

# %% [markdown]
# - Построим "ящик с усами" для оценки выбросов.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(
    12, 8), gridspec_kw={'wspace': 1.3})

# График длительности клиентов
df_numeric.boxplot(column=['duration'], ax=axes[0], grid=True)
axes[0].set_title('Длительность действия договора', y=1.03, fontsize=20)
axes[0].set_ylabel('Длительность действия договора, дни', fontsize=16)
axes[0].set_xlabel('')

# График месячных платежей
df_numeric.boxplot(column=['monthly_charges'], ax=axes[1], grid=True)
axes[1].set_title('Месячные платежи', y=1.03, fontsize=20)
axes[1].set_ylabel('Месячные платежи, $', fontsize=16)
axes[1].set_xlabel('')

plt.tight_layout()
plt.show()
plt.close()
# Out:
# /var/folders/mz/b2hbqf51521_fzm8c30chvf40000gn/T/ipykernel_21203/3893971940.py:16: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
df_numeric = df_merge[['monthly_charges',
                       'exited',
                       'duration',
                       'total_charges']
                      ]

# %%
# Одномерная гистограмма
fig, ax = plt.subplots(figsize=(18, 11))
sns.histplot(df_numeric['monthly_charges'], bins=30,
             kde=True, color='blue', alpha=0.5, ax=ax)
ax.set_title('Распределение ежемесячной оплаты', y=1.03, fontsize=20)
ax.set_xlabel('Ежемесячная оплата', fontsize=16)
ax.set_ylabel('Количество, человек', fontsize=16)
plt.show()
plt.close()
print()

# Ящик с усами
fig, ax = plt.subplots(figsize=(12, 8))
sns.boxplot(x='exited', y='duration', data=df_numeric, ax=ax)
ax.set_title(
    'Длительность действия договора клиентов по группам "ушедшие"/"оставшиеся"', y=1.03, fontsize=20)
ax.set_xlabel('Группа "ушедшие"/"оставшиеся"', fontsize=16)
ax.set_ylabel('Длительность, месяцы', fontsize=16)
plt.show()
plt.close()

# %% [markdown]
# - проверим качественные данные на мультикколлениарность, которая может ослабить статистическую мощность модели

# %%
phik_overview = df_merge.drop(['monthly_charges',
                               'total_charges',
                               'senior_citizen',
                               'duration'], axis=1).phik_matrix()
phik_overview['exited'].sort_values(ascending=False)
# Out:
# interval columns not set, guessing: ['exited']
# exited               1.000000
# multiple_lines       0.261345
# online_backup        0.229736
# partner              0.227597
# streaming_movies     0.221756
# device_protection    0.218622
# payment_method       0.214300
# streaming_tv         0.200334
# online_security      0.132914
# tech_support         0.103933
# type                 0.094622
# paperless_billing    0.082789
# internet_service     0.056279
# dependents           0.048710
# gender               0.008800
# Name: exited, dtype: float64

# %% [markdown]
# - проверим количественные данные на мультикколлениарность, которая может ослабить статистическую мощность модели

# %%
df_numeric = df_merge[['monthly_charges',
                       'total_charges',
                       'duration']
                      ]

# %%
sns.set(font_scale=1.15)
plt.figure(figsize=(15, 4))
sns.heatmap(
    df_numeric.corr(),
    cmap='RdBu_r',  # задаёт цветовую схему
    annot=True,  # рисует значения внутри ячеек
    vmin=-1, vmax=1)  # указывает начало цветовых кодов от -1 до 1.
plt.show()
plt.close()

# %%
df_numeric = df_merge[['monthly_charges',
                       'exited',
                       'duration',
                       'total_charges']
                      ]

# %%
g = sns.pairplot(df_numeric,
                 hue='exited',
                 diag_kind='kde',
                 diag_kws=dict(shade=True),
                 height=5,
                 palette=['#52BE80',
                          '#FF5733'],
                 plot_kws=dict(s=30,
                               linewidth=0.5)
                 )

g.fig.subplots_adjust(top=0.95)
g.fig.suptitle('Взаимосвязи между всеми парами числовых признаков',
               fontsize=23,
               y=1.0
               )

g.axes[1, 0].set_xlabel('Monthly Charges', fontsize=16)
g.axes[1, 0].set_ylabel('Total Charges', fontsize=16)

g.axes[2, 0].set_xlabel('Monthly Charges', fontsize=16)
g.axes[2, 0].set_ylabel('Duration', fontsize=16)

g.axes[2, 1].set_xlabel('Total Charges', fontsize=16)
g.axes[2, 1].set_ylabel('Duration', fontsize=16)

plt.show()
plt.close()
# Out:
# /Users/anaconda/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:1507: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=vector, **plot_kwargs)
# /Users/anaconda/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:1507: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=vector, **plot_kwargs)
# /Users/anaconda/anaconda3/lib/python3.9/site-packages/seaborn/axisgrid.py:1507: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=vector, **plot_kwargs)

# %% [markdown]
# #### Выводы:
# По графикам мы видим, что клиенты, ушедшие из компании:
# - клиенты, ушедшие из компании суммарно заплатили меньше, чем те, которые остались в компании;
# - клиенты, ушедшие из компании в среднем имели менее широкую и среднюю длительность сотрудничества с компанией;
# - клиенты оставшиеся в компании, имели обратно пропорциональную зависимость: чем меньше общие затраты, тем дольше они были в компании;
# - клиенты, ушедшие из компани имели общие затраты приблизительно среднего уровня, а оставшиеся в компании имели два пика: очень высокие затраты и маленькие затраты.

# %%
df_numeric = df_merge[['monthly_charges',
                       'exited',
                       'duration',
                       'senior_citizen',
                       'total_charges']
                      ]

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(22, 10))
sns.heatmap(
    df_merge.phik_matrix(interval_cols=df_numeric),
    cmap='RdBu_r',
    annot=True,
    annot_kws={"size": 14},
    vmin=-1, vmax=1)
plt.title("Phik корреляция между бинарными и категориальными признаками",
          fontsize=23, y=1.03)
plt.show()
plt.close()

# %% [markdown]
# - Мы видим сильную кореляцию между `total_charges` и `duration` , поэтому столбец `total_charges` удалим.

# %%
df_merge = df_merge.drop('total_charges', axis=1)

# %% [markdown]
# - Проверим на дубликаты после проведенной обработки данных

# %%
print(df_merge.duplicated().sum())
# Out:
# 22

# %% [markdown]
# - Удалим дубликаты

# %%
df_merge = df_merge.drop_duplicates()

# %% [markdown]
# - С помощью `sweetviz` создадим сводный отчет по объединенной таблице (df_merge)

# %%
# report = sv.analyze([df_merge, "Info_df_merge_1.0"])

# %% [markdown]
# - С помощью `pandas_profiling.ProfileReport` создадим сводный отчет по объединенной таблице (df_merge)

# %%
# pandas_profiling.ProfileReport(df_merge)

# %% [markdown]
# ##### Вывод:
# - среди качественных признаков мультикколлениарность не выявлена;
# - вреди количественных признаков выявлена мультикколлениарность между двумя признакамми: `total_charges` и `duration` , поэтому столбец `total_charges` удалили;
# - при анализе гистограмм числовых признаков и при анализе "ящиков с усами" для оценки выбросов аномалий не выявлено;
# - подготовка, исследовательский анализ, предобработка данных выполнены, теперь можно начать подготовку и обработку данных.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Объявим переменные:
# - features_* — запишем в неё признаки;
# - target_* — запишем в неё целевой признак.
#
# Разобьем данные на три выборки:
#  1. " *_train " - обучающая (для обучения);
#  1. " *_test " - тестовая (для тестирования качества модели);
#
# Соотношение выборок по размеру данных будет следующим:
# - *_train : *_test = 3:1

# %%
features = df_merge.drop(['exited'], axis=1)
target = df_merge['exited']

features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.25, random_state=100423)

# %%
# категориальные признаки для OHE
ohe_features = features_train.select_dtypes(include='object').columns.to_list()

# %%
# численные признаки
num_features = features_train.select_dtypes(exclude='object').columns.to_list()

# %%
features_train_ohe = features_train.copy()

features_test_ohe = features_test.copy()

# %%
# получились одинаковые признаки в тренировочной и тестовой выборках
(features_train_ohe.columns != features_test_ohe.columns).sum()
# Out:
# 0

# %%
display(df_merge.columns)
# Out:
# Index(['type', 'paperless_billing', 'payment_method', 'monthly_charges',
#        'gender', 'senior_citizen', 'partner', 'dependents', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'multiple_lines', 'exited',
#        'duration'],
#       dtype='object')

# %%
# drop='first' удаляет первый признак из закодированных:
# таким образом обходим dummy-ловушку
# задаём handle_unknown='ignore':
# игнорируется ранее невстречающиеся значения признака (при transform)
encoder_ohe = OneHotEncoder(
    drop='first', handle_unknown='ignore', sparse=False)

# обучаем энкодер на заданных категориальных признаках тренировочной выборки
encoder_ohe.fit(features_train_ohe[ohe_features])

# добавляем закодированные признаки в X_train_ohe
# encoder_ohe.get_feature_names_out() позволяет получить названия колонок
features_train_ohe[
    encoder_ohe.get_feature_names_out()
] = encoder_ohe.transform(features_train_ohe[ohe_features])

# удаляем незакодированные категориальные признаки (изначальные колонки)
features_train_ohe = features_train_ohe.drop(ohe_features, axis=1)

# создаём скелер
scaler = StandardScaler()

# обучаем его на численных признаках тренировочной выборки, трансформируем её же
features_train_ohe[num_features] = scaler.fit_transform(
    features_train_ohe[num_features])

# смотрим на результат
features_train_ohe.head()
# Out:
#              monthly_charges  duration  type_One year  type_Two year  \
# customer_id
# 1559-DTODC         -1.326197 -0.472603            0.0            0.0
# 2812-SFXMJ         -1.495452 -1.277979            0.0            0.0
# 9283-LZQOH          0.308275 -0.653042            0.0            0.0
# 9572-MTILT          1.381883 -0.119059            0.0            0.0
# 9475-NNDGC          1.594281  1.849637            1.0            0.0
#
#              paperless_billing_Yes  payment_method_Credit card (automatic)  \
# customer_id
# 1559-DTODC                     1.0                                     0.0
# 2812-SFXMJ                     0.0                                     0.0
# 9283-LZQOH                     1.0                                     1.0
# 9572-MTILT                     1.0                                     0.0
# 9475-NNDGC                     1.0                                     0.0
#
# ...

# %%
# энкодером, который обучен на ТРЕНИРОВОЧНОЙ ВЫБОРКЕ, кодируем тестовую
features_test_ohe[
    encoder_ohe.get_feature_names_out()
] = encoder_ohe.transform(features_test_ohe[ohe_features])

features_test_ohe = features_test_ohe.drop(ohe_features, axis=1)

# скелером, который обучен на ТРЕНИРОВОЧНОЙ ВЫБОРКЕ, масштабируем тестовую
features_test_ohe[num_features] = scaler.transform(
    features_test_ohe[num_features]
)

# смотрим на результат
features_test_ohe.head()
# Out:
#              monthly_charges  duration  type_One year  type_Two year  \
# customer_id
# 2833-SLKDQ         -0.665771 -1.143016            0.0            0.0
# 8436-BJUMM          0.618576 -0.117592            0.0            0.0
# 4709-LKHYG         -1.497112 -0.028106            1.0            0.0
# 9907-SWKKF         -1.329516 -1.143016            0.0            0.0
# 9681-OXGVC          1.174462 -1.008053            0.0            0.0
#
#              paperless_billing_Yes  payment_method_Credit card (automatic)  \
# customer_id
# 2833-SLKDQ                     0.0                                     0.0
# 8436-BJUMM                     1.0                                     0.0
# 4709-LKHYG                     0.0                                     0.0
# 9907-SWKKF                     0.0                                     0.0
# 9681-OXGVC                     1.0                                     0.0
#
# ...

# %%
# получилось одинаковое количество признаков
features_train_ohe.shape, features_test_ohe.shape
# Out:
# ((5257, 21), (1753, 21))

# %%
# получились одинаковые признаки в тренировочной и тестовой выборках
(features_train_ohe.columns != features_test_ohe.columns).sum()
# Out:
# 0

# %% [markdown]
# - Выведем список признаков, на которых будем обучать модели.

# %%
display(features_train_ohe.columns)
# Out:
# Index(['monthly_charges', 'duration', 'type_One year', 'type_Two year',
#        'paperless_billing_Yes', 'payment_method_Credit card (automatic)',
#        'payment_method_Electronic check', 'payment_method_Mailed check',
#        'gender_Male', 'senior_citizen_1', 'partner_Yes', 'dependents_Yes',
#        'internet_service_Fiber optic', 'internet_service_No',
#        'online_security_Yes', 'online_backup_Yes', 'device_protection_Yes',
#        'tech_support_Yes', 'streaming_tv_Yes', 'streaming_movies_Yes',
#        'multiple_lines_Yes'],
#       dtype='object')

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# Обучим и подберем лучшие гиперпараметры для следующих моделей:
#  - RandomForestClassifier (GridSearchCV);
#  - CatBoost [закодированные признаки] (GridSearchCV);
#  - LightGBMClassifier (GridSearchCV).

# %% [markdown]
# #### RandomForestClassifier (GridSearchCV)

# %%
# %%time

grid_params_RFC = {'max_depth': np.arange(1, 110, 50),
                   'max_features': ['log2', 'sqrt'],
                   'min_samples_leaf': [x for x in range(2, 10, 5)],
                   'n_estimators': [x for x in range(500, 810, 100)],
                   'class_weight': ['balanced', None]
                   }

model_forest = RandomForestClassifier(random_state=100423)

print('# Tuning hyper-parameters for ROC-AUC')
print()
grid_RFC = GridSearchCV(model_forest,
                        param_grid=grid_params_RFC,
                        cv=5,
                        verbose=1,
                        n_jobs=-1,
                        scoring='roc_auc'
                        )


grid_RFC.fit(features_train_ohe, target_train)
print("Best parameters set found on development set:")
print()
print(grid_RFC.best_params_)
print()

cv_roc_auc_RFC = grid_RFC.best_score_

print("ROC_AUC модели 'RandomForestClassifier' с лучшими параметрами :",
      round(cv_roc_auc_RFC, 3))
# Out:
# # Tuning hyper-parameters for ROC-AUC
#
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Best parameters set found on development set:
#
# {'class_weight': 'balanced', 'max_depth': 51, 'max_features': 'log2', 'min_samples_leaf': 7, 'n_estimators': 600}
#
# ROC_AUC модели 'RandomForestClassifier' с лучшими параметрами : 0.824
# CPU times: user 4.92 s, sys: 340 ms, total: 5.26 s
# Wall time: 3min 24s

# %%
best_model = grid_RFC.best_estimator_

cv_scores = cross_val_score(best_model, features_train_ohe, target_train, cv=5)

print("Cross-validation accuracy scores модели 'RandomForestClassifier':", cv_scores)
print()
print("Mean accuracy модели 'RandomForestClassifier':", round(cv_scores.mean(), 3))
# Out:
# Cross-validation accuracy scores модели 'RandomForestClassifier': [0.79277567 0.82509506 0.81255947 0.79448145 0.80304472]
#
# Mean accuracy модели 'RandomForestClassifier': 0.806

# %% [markdown]
# #### CatBoost [закодированные признаки] (GridSearchCV)

# %%
# %%time

grid_params_CBC = {'learning_rate': np.arange(0.01, 0.2, 0.05),
                   'depth': np.arange(2, 15, 3),
                   'random_state': [100423],
                   'verbose': [False]
                   }

model_CBC = CatBoostClassifier(random_state=100423,
                               loss_function='CrossEntropy',
                               iterations=200
                               )

print('# Tuning hyper-parameters for ROC-AUC')
print()
grid_CBC = GridSearchCV(model_CBC,
                        param_grid=grid_params_CBC,
                        cv=5,
                        verbose=0,
                        n_jobs=-1,
                        scoring='roc_auc'
                        )


grid_CBC.fit(features_train_ohe, target_train)
print("Best parameters set found on development set:")
print()
print(grid_CBC.best_params_)
print()

cv_roc_auc_CBC = grid_CBC.best_score_

print("ROC_AUC модели 'CatBoostClassifier[закодированные признаки]' с лучшими параметрами :", round(
    cv_roc_auc_CBC, 3))
# Out:
# # Tuning hyper-parameters for ROC-AUC
#
# Best parameters set found on development set:
#
# {'depth': 5, 'learning_rate': 0.16000000000000003, 'random_state': 100423, 'verbose': False}
#
# ROC_AUC модели 'CatBoostClassifier[закодированные признаки]' с лучшими параметрами : 0.905
# CPU times: user 2.14 s, sys: 805 ms, total: 2.95 s
# Wall time: 7min 57s

# %%
best_model = grid_CBC.best_estimator_

cv_scores = cross_val_score(best_model, features_train_ohe, target_train, cv=5)

print(
    "Cross-validation accuracy scores модели 'CatBoostClassifier[закодированные признаки]':", cv_scores)
print()
print("Mean accuracy модели 'CatBoostClassifier[закодированные признаки]':", round(
    cv_scores.mean(), 3))
# Out:
# Cross-validation accuracy scores модели 'CatBoostClassifier[закодированные признаки]': [0.89638783 0.91444867 0.90009515 0.90675547 0.90390105]
#
# Mean accuracy модели 'CatBoostClassifier[закодированные признаки]': 0.904

# %% [markdown]
# #### LightGBMClassifier (GridSearchCV)

# %%
# %%time

grid_params_LGBMC = {'num_leaves': [7, 15, 31],
                     'learning_rate': np.arange(0.10, 0.21, 0.05),
                     'n_estimators': [50, 100, 200],
                     'min_child_samples': [5, 10, 20],
                     'reg_alpha': [0, 0.1, 0.5],
                     'reg_lambda': [0, 0.1, 0.5],
                     'random_state': [100423]
                     }

model_LGBMC = LGBMClassifier()

print('# Tuning hyper-parameters for ROC-AUC')
print()
grid_LGBMC = GridSearchCV(model_LGBMC,
                          param_grid=grid_params_LGBMC,
                          cv=5,
                          n_jobs=-1,
                          verbose=0,
                          scoring='roc_auc'
                          )

grid_LGBMC.fit(features_train_ohe, target_train)
print("Best parameters set found on development set:")
print()
print(grid_LGBMC.best_params_)
print()

cv_roc_auc_LGBMR = grid_LGBMC.best_score_

print("ROC-AUC модели 'LightGBMClassifier' с лучшими параметрами на тренировочном наборе данных:",
      round(cv_roc_auc_LGBMR, 3))
# Out:
# # Tuning hyper-parameters for ROC-AUC
# /Users/anaconda/anaconda3/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best parameters set found on development set:
#
# {'learning_rate': 0.20000000000000004, 'min_child_samples': 5, 'n_estimators': 200, 'num_leaves': 7, 'random_state': 100423, 'reg_alpha': 0, 'reg_lambda': 0}
#
# ROC-AUC модели 'LightGBMClassifier' с лучшими параметрами на тренировочном наборе данных: 0.904
# CPU times: user 13.9 s, sys: 930 ms, total: 14.9 s
# Wall time: 1min 15s

# %%
best_model = grid_LGBMC.best_estimator_

cv_scores = cross_val_score(best_model, features_train_ohe, target_train, cv=5)

print("Cross-validation accuracy scores модели 'LightGBMClassifier':", cv_scores)
print()
print("Mean accuracy модели 'LightGBMClassifier':", round(cv_scores.mean(), 3))
# Out:
# Cross-validation accuracy scores модели 'LightGBMClassifier': [0.91730038 0.91254753 0.90390105 0.90294957 0.905804  ]
#
# Mean accuracy модели 'LightGBMClassifier': 0.909

# %%
plt.figure(figsize=[12, 9])

plt.plot([0, 1], [0, 1], linestyle='--', label='RandomModel')

RFC_probs = cross_val_predict(grid_RFC.best_estimator_, features_train_ohe,
                              target_train, cv=5, method='predict_proba')[:, 1]
fpr, tpr, thresholds = roc_curve(target_train, RFC_probs)
auc_roc_RFC_train = roc_auc_score(target_train, RFC_probs)
accuracy_RFC_train = accuracy_score(
    target_train, grid_RFC.predict(features_train_ohe))
plt.plot(fpr, tpr, label='RandomForestClassifier_train')

CBC_probs = cross_val_predict(grid_CBC.best_estimator_, features_train_ohe,
                              target_train, cv=5, method='predict_proba')[:, 1]
fpr, tpr, thresholds = roc_curve(target_train, CBC_probs)
auc_roc_CBC_train = roc_auc_score(target_train, CBC_probs)
accuracy_CBC_train = accuracy_score(
    target_train, grid_CBC.predict(features_train_ohe))
plt.plot(fpr, tpr, label='CatBoostClassifier_train')

LGBMC_probs = cross_val_predict(
    grid_LGBMC.best_estimator_, features_train_ohe, target_train, cv=5, method='predict_proba')[:, 1]
fpr, tpr, thresholds = roc_curve(target_train, LGBMC_probs)
auc_roc_LGBMC_train = roc_auc_score(target_train, LGBMC_probs)
accuracy_LGBMC_train = accuracy_score(
    target_train, grid_LGBMC.predict(features_train_ohe))
plt.plot(fpr, tpr, label='LightGBMClassifier_train')


plt.xlim([0, 1])
plt.ylim([0, 1])

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.legend(loc='lower right', fontsize=14)

plt.title("ROC-кривая", fontsize=23, y=1.02)
plt.show()
plt.close()

# %% [markdown]
# ### Проверим наилучшие параметры лучшей модели на тестовой выборке.

# %% [markdown]
# #### CatBoostClassifier

# %%
# %%time

model_CBC_test = CatBoostClassifier(learning_rate=0.16,
                                    depth=5,
                                    verbose=False,
                                    random_state=100423
                                    )

model_CBC_test.fit(features_train_ohe, target_train)


predict_proba = model_CBC_test.predict_proba(features_test_ohe)[:, 1]

ROC_AUC = round((roc_auc_score(target_test, predict_proba)), 3)
print('ROC_AUC модели "CatBoostClassifier" на тестовой выборке:', ROC_AUC)
# Out:
# ROC_AUC модели "CatBoostClassifier" на тестовой выборке: 0.914
# CPU times: user 6.54 s, sys: 721 ms, total: 7.26 s
# Wall time: 1.79 s

# %%
y_pred = model_CBC_test.predict(features_test_ohe)

accuracy = accuracy_score(target_test, y_pred)
print("Accuracy модели 'CatBoostClassifier' :", round(accuracy, 3))
# Out:
# Accuracy модели 'CatBoostClassifier' : 0.925

# %%
plt.figure(figsize=[12, 9])

plt.plot([0, 1], [0, 1], linestyle='--', label='RandomModel')

probabilities_test = grid_CBC.best_estimator_.predict_proba(features_test_ohe)[
    :, 1]
probabilities_one_test = probabilities_test
fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test)
auc_roc_CBC_test = roc_auc_score(target_test, probabilities_test)
accuracy_CBC_test = accuracy_score(
    target_test, grid_CBC.predict(features_test_ohe))
plt.plot(fpr, tpr, label='CatBoostClassifier_test')

plt.xlim([0, 1])
plt.ylim([0, 1])

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.legend(loc='lower right', fontsize=14)

plt.title("ROC-кривая", fontsize=23, y=1.02)
plt.show()
plt.close()

# %% [markdown]
# - Проведем анализ важности признаков на тестовой выборке. Это может нам позволить определить наиболее важные признаки для обучения, сконцентрироваться на них и улучшить метрику.

# %%
# Создаем DataFrame с данными о важности признаков и сортируем его по убыванию важности
feat_import = pd.DataFrame(
    data={'feature': features_train_ohe.columns, 'percent': model_CBC_test.feature_importances_})
feat_import_sorted = feat_import.sort_values(
    'percent', ascending=False).reset_index(drop=True)
display(feat_import_sorted)

# Создаем график
plt.figure(figsize=(13, 8))
plt.bar(x=feat_import_sorted['feature'], height=feat_import_sorted['percent'])
plt.xticks(rotation=90)
plt.xlabel('Features')
plt.ylabel('Importance, %')
plt.title('Feature Importance')
plt.show()
plt.close()
# Out:
#                                    feature    percent
# 0                                 duration  47.137626
# 1                          monthly_charges  17.192497
# 2                              partner_Yes   4.023399
# 3                            type_Two year   3.892385
# 4                       multiple_lines_Yes   2.766791
# 5                        online_backup_Yes   2.335236
# 6   payment_method_Credit card (automatic)   2.127021
# 7                    device_protection_Yes   2.120247
# 8                     streaming_movies_Yes   2.082632
# 9                            type_One year   2.036334
# 10                          dependents_Yes   1.983175
# 11             payment_method_Mailed check   1.861131
# 12                   paperless_billing_Yes   1.754225
# 13                     online_security_Yes   1.748168
# 14                        senior_citizen_1   1.565026
# 15                             gender_Male   1.450719
# ...

# %% [markdown]
# ##### Вывод:
# - Из трех моделей на тренировочной выборке только две модели показали результат `ROC_AUC` >= 0.85:
#
#   - CatBoostClassifier:
#      - `ROC_AUC`=0.905  и `Accuracy`=0.904;
#
#   - LightGBMClassifier:
#      - `ROC_AUC`=0.904 и `Accuracy`=0.909;
#
#
# - Самые лучшие рузультаты на тренировочной выборке показала модель `CatBoostClassifier`;
#
#
# - На тестовой выборке модель `CatBoostClassifier` показала результат `ROC_AUC` = 0.914 и `Accuracy` = 0.925

# %% [markdown]
# # Отчет:
#
#
# ## Проект: Прототип модели машинного обучения для «Оператора связи "Ниединогоразрыва.ком"».
#
# - Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.
#
#
# ### Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 1. Интернет. Подключение может быть двух типов: через телефонную линию (DSL*,* от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*).
#
# Также доступны такие услуги:
#
# 1. Интернет-безопасность: антивирус (*DeviceProtection*) и блокировка небезопасных сайтов (*OnlineSecurity*);
# 1. Выделенная линия технической поддержки (*TechSupport*);
# 1. Облачное хранилище файлов для резервного копирования данных (*OnlineBackup*);
# 1. Стриминговое телевидение (*StreamingTV*) и каталог фильмов (*StreamingMovies*).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.
#
#
# #### Нами были выполнены следующие этапы исследования:
#
# 1. Общий обзор данных:
#   - выведение сводной информации о датасетах;
#   - объединение датасетов для дальнейшей работы;
#   - корректировка названия столбов; выведение примера таблицы;
# 2. Провести предобработку данных:
#   - проверка на дубликаты;
#   - анализ пропусков и их обработка;
#   - унифицирование данных столбцов;
#   - удаление лишних столбцов;
#   - поиск аномальных значений в столбцах и их обработка;
#   - выведение статистических характеристик числовых признаков;
#   - построение гистограмм числовых признаков;
#   - построение "ящика с усами" для оценки выбросов;
#   - проверкам качественных данных на мультикколлениарность, которая может ослабить статистическую мощность модели;
#   - выявление взаимосвязи между всеми парами числовых признаков; выявление Phik корреляции между бинарными и категориальными признаками;
#   - проверка на дубликаты после проведенной обработки данных и их удаление;
# 3. Анализ данных:
#   - объявление переменных `target` и `features`;
#   - разделение датасета на тренировочную и тестовую выборку;
#   - применение *One-Hot Encoder* прямого метода кодирования данных (*One-Hot Encoder*);
#   - обучение моделей осуществлялось на следующих признаках: 'monthly_charges', 'duration', 'type_One year', 'type_Two year', 'paperless_billing_Yes', 'payment_method_Credit card (automatic)', 'payment_method_Electronic check', 'payment_method_Mailed check', 'gender_Male', 'senior_citizen_1', 'partner_Yes', 'dependents_Yes', 'internet_service_Fiber optic', 'internet_service_No', 'online_security_Yes', 'online_backup_Yes', 'device_protection_Yes', 'tech_support_Yes', 'streaming_tv_Yes', 'streaming_movies_Yes', 'multiple_lines_Yes';
#   - обучение и подбор лучших гиперпараметров для моделей RandomForestClassifier [GridSearchCV], CatBoost [закодированные признаки] [GridSearchCV], LightGBMClassifier [GridSearchCV];
#   - построение ROC-кривых на тренировочной выборке для выше перечисленных моделей;
#   - проверка наилучших параметров лучшей модели (CatBoost [закодированные признаки] [GridSearchCV]) на тестовой выборке и построение ROC-кривой на тестовой выборке для данной модели;
#   - проведение анализа важности признаков на тестовой выборке, что может нам позволить определить наиболее важные признаки для обучения и сконцентрироваться на них, и улучшить метрику);
# 4. Вывод и заключение.
#
#
# #### Нами были выполнены все условия:
# 1. Использовать бизнес-метрики:
#   - Основная метрика: AUC-ROC (метрика, которая учитывает возможность балансировать между false posititve и false negative.); целевое значение AUC-ROC >= 0.85
#   - Дополнительная метрика: Accuracy;
# 2. Использовать значение RANDOM_STATE = 100423;
# 3. Размер тестовой выборки: test_size = 0.25;
# 4. Проверить корреляцию числовых и качественных признаков на наличие мультиколлинеарности;
# 5. Рассмотреть как минимум две (а лучше три) модели машинного обучения, например случайный лес и градиентный бустинг. При использовании только двух моделей нельзя использовать две вариации градиентного бустинга. Модели, которые мы использовали:
#   - RandomForestClassifier [GridSearchCV];
#   - CatBoostClassifier [закодированные признаки] [GridSearchCV];
#   - LightGBMClassifier [GridSearchCV];
#
#
# #### В результате исследования мы смогли сделать следующие выводы:
# 1. После анализа графиков данных мы можем выдвинуть гипотезу, что клиенты, ушедшие из компании:
# - клиенты, ушедшие из компании суммарно заплатили меньше, чем те, которые остались в компании;
# - клиенты, ушедшие из компании в среднем имели менее широкую и среднюю длительность сотрудничества с компанией;
# - клиенты оставшиеся в компании, имели обратно пропорциональную зависимость: чем меньше общие затраты, тем дольше они были в компании;
# - клиенты, ушедшие из компани имели общие затраты приблизительно среднего уровня, а оставшиеся в компании имели два пика: очень высокие затраты и маленькие затраты.
# 2. среди качественных признаков мультикколлениарность не выявлена;
# 3. среди количественных признаков выявлена мультикколлениарность между двумя признакамми: `total_charges` и `duration` , поэтому столбец `total_charges` удалили;
# 4. при анализе гистограмм числовых признаков и при анализе "ящиков с усами" для оценки выбросов аномалий не выявлено;
# 5. из трех моделей на тренировочной выборке только две модели показали результат `ROC_AUC` >= 0.85:
#   - CatBoostClassifier:
#      - `ROC_AUC`=0.905  и `Accuracy`=0.904;
#   - LightGBMClassifier:
#      - `ROC_AUC`=0.904 и `Accuracy`=0.909;
# 6.  Самые лучшие рузультаты на тренировочной выборке показала модель `CatBoostClassifier`;
# 7.  На тестовой выборке модель `CatBoostClassifier` показала результат `ROC_AUC` = 0.914 и `Accuracy` = 0.925.
#
#
# #### Заключение:
# Для достажения поставленной цели: "Построить модель для прогнозирования оттока клиентов.", мы можем рекомендовать модель CatBoostClassifier со следующими гиперпараметрами:
#  - learning_rate=0.16;
#  - depth=5;
#  - verbose=False;
#  - random_state=100423.
#
#
#
# Все этапы проекта были важны. Однако, по нашему мнению ключевым этапом, который позволил добиться высокого значения метрики, был этап предобработки данных. Потому что именно он является краеугольным камнем любого анализа.
